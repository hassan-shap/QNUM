# %%
q 0.5 F 1.0 user pair ('NETLPGH', 'PSFC') edges ["('NETLPGH',80):L=159.491214", "(80,'EQXDC4'):L=106.327476", "('EQXDC4',112):L=148.59658", '(112,110):L=108.83139999999999', "(110,'NEWY1118TH'):L=111.20933", "('NEWY1118TH',46):L=50.43786666666667", '(46,45):L=50.43786666666667', '(45,44):L=50.43786666666667', '(44,42):L=100.87573333333334', "(42,'PSFC'):L=51.70702666666667"] W 5.0 
q 0.5 F 1.0 user pair ('NETLMGN', 'PPPL') edges ["('NETLMGN',85):L=59.92605", '(85,84):L=59.92605', '(84,83):L=59.92605', "(83,'EQXDC4'):L=59.92605", "('EQXDC4','WASH'):L=39.76518", "('WASH',117):L=52.043690000000005", '(117,116):L=52.043690000000005', '(116,115):L=52.043690000000005', '(115,114):L=52.043690000000005', "(114,'PPPL'):L=52.043690000000005"] W 5.0 
q 0.5 F 1.0 user pair ('BNL', 'JLAB') edges ["('BNL','NEWY32AOA'):L=96.79889", "('NEWY32AOA',109):L=54.415699999999994", '(109,110):L=54.415699999999994', '(110,111):L=54.415699999999994', '(111,112):L=54.415699999999994', '(112,113):L=54.415699999999994', "(113,'WASH'):L=54.415699999999994", "('WASH',86):L=100.007515", '(86,87):L=60.242335', '(87,88):L=60.242335', "(88,'JLAB'):L=60.242335"] W 5.0 
q 0.5 F 1.0 user pair ('SRS', 'ORAU') edges ["('SRS',4):L=61.8882075", '(4,3):L=61.8882075', '(3,2):L=61.8882075', "(2,'ATLA'):L=61.8882075", "('ATLA',21):L=56.3069", '(21,22):L=56.3069', '(22,23):L=56.3069', "(23,'ORAU'):L=56.3069"] W 10.0 
q 0.5 F 1.0 user pair ('Y12', 'FNAL') edges ["('Y12','CHAT'):L=422.5253", "('CHAT',61):L=217.69351416666666", '(61,59):L=108.15942833333334', '(59,56):L=162.2391425', '(56,55):L=54.07971416666667', '(55,53):L=108.15942833333334', "(53,'STAR'):L=164.40257250000002", "('STAR','FNAL'):L=53.14691"] W 5.0 
q 0.5 F 1.0 user pair ('ORNL', 'ANL') edges ["('ORNL',61):L=297.0893541666667", '(61,58):L=162.2391425', '(58,55):L=162.2391425', '(55,52):L=162.2391425', "(52,'ANL'):L=147.06573833333334"] W 5.0

# %%
q 1.0 F 0.99 user pair ('NETLPGH', 'PSFC') edges ["('NETLPGH',80):L=159.491214", "(80,'EQXDC4'):L=106.327476", "('EQXDC4',112):L=148.59658", '(112,110):L=108.83139999999999', "(110,'NEWY1118TH'):L=111.20933", "('NEWY1118TH',46):L=50.43786666666667", '(46,45):L=50.43786666666667', '(45,44):L=50.43786666666667', '(44,42):L=100.87573333333334', "(42,'PSFC'):L=51.70702666666667"] W 5.0 
q 1.0 F 0.99 user pair ('NETLMGN', 'PPPL') edges ["('NETLMGN',85):L=59.92605", '(85,84):L=59.92605', '(84,83):L=59.92605', "(83,'EQXDC4'):L=59.92605", "('EQXDC4','WASH'):L=39.76518", "('WASH',117):L=52.043690000000005", '(117,116):L=52.043690000000005', '(116,115):L=52.043690000000005', '(115,114):L=52.043690000000005', "(114,'PPPL'):L=52.043690000000005"] W 5.0 
q 1.0 F 0.99 user pair ('BNL', 'JLAB') edges ["('BNL','NEWY32AOA'):L=96.79889", "('NEWY32AOA',109):L=54.415699999999994", '(109,110):L=54.415699999999994', '(110,111):L=54.415699999999994', '(111,112):L=54.415699999999994', '(112,113):L=54.415699999999994', "(113,'WASH'):L=54.415699999999994", "('WASH',86):L=100.007515", '(86,87):L=60.242335', '(87,88):L=60.242335', "(88,'JLAB'):L=60.242335"] W 5.0 
q 1.0 F 0.99 user pair ('SRS', 'ORAU') edges ["('SRS',4):L=61.8882075", '(4,3):L=61.8882075', '(3,2):L=61.8882075', "(2,'ATLA'):L=61.8882075", "('ATLA',21):L=56.3069", '(21,22):L=56.3069', '(22,23):L=56.3069', "(23,'ORAU'):L=56.3069"] W 10.0 
q 1.0 F 0.99 user pair ('Y12', 'FNAL') edges ["('Y12','CHAT'):L=422.5253", "('CHAT','NASH'):L=163.6138", "('NASH',59):L=162.2391425", '(59,56):L=162.2391425', '(56,55):L=54.07971416666667', '(55,53):L=108.15942833333334', "(53,'STAR'):L=164.40257250000002", "('STAR','FNAL'):L=53.14691"] W 5.0 
q 1.0 F 0.99 user pair ('ORNL', 'ANL') edges ["('ORNL',61):L=297.0893541666667", '(61,58):L=162.2391425', '(58,55):L=162.2391425', '(55,52):L=162.2391425', "(52,'ANL'):L=147.06573833333334"] W 5.0

# %%
user_pairs = [('NETLPGH', 'PSFC'), ('NETLMGN', 'PPPL'), ('BNL', 'JLAB'), ('SRS', 'ORAU'), ('Y12', 'FNAL'),('ORNL', 'ANL')]
paths = [ ('NETLPGH',80), (80,'EQXDC4'), ('EQXDC4',112), (112,110), (110,'NEWY1118TH'), ('NEWY1118TH',46), (46,45), (45,44), (44,42), (42,'PSFC')]
 ["('NETLMGN',85):L=59.92605", '(85,84):L=59.92605', '(84,83):L=59.92605', "(83,'EQXDC4'):L=59.92605", "('EQXDC4','WASH'):L=39.76518", "('WASH',117):L=52.043690000000005", '(117,116):L=52.043690000000005', '(116,115):L=52.043690000000005', '(115,114):L=52.043690000000005', "(114,'PPPL'):L=52.043690000000005"] W 5.0 
# q 0.5 F 1.0 user pair ('BNL', 'JLAB') edges ["('BNL','NEWY32AOA'):L=96.79889", "('NEWY32AOA',109):L=54.415699999999994", '(109,110):L=54.415699999999994', '(110,111):L=54.415699999999994', '(111,112):L=54.415699999999994', '(112,113):L=54.415699999999994', "(113,'WASH'):L=54.415699999999994", "('WASH',86):L=100.007515", '(86,87):L=60.242335', '(87,88):L=60.242335', "(88,'JLAB'):L=60.242335"] W 5.0 
# q 0.5 F 1.0 user pair ('SRS', 'ORAU') edges ["('SRS',4):L=61.8882075", '(4,3):L=61.8882075', '(3,2):L=61.8882075', "(2,'ATLA'):L=61.8882075", "('ATLA',21):L=56.3069", '(21,22):L=56.3069', '(22,23):L=56.3069', "(23,'ORAU'):L=56.3069"] W 10.0 
# q 0.5 F 1.0 user pair ('Y12', 'FNAL') edges ["('Y12','CHAT'):L=422.5253", "('CHAT',61):L=217.69351416666666", '(61,59):L=108.15942833333334', '(59,56):L=162.2391425', '(56,55):L=54.07971416666667', '(55,53):L=108.15942833333334', "(53,'STAR'):L=164.40257250000002", "('STAR','FNAL'):L=53.14691"] W 5.0 
# q 0.5 F 1.0 user pair ('ORNL', 'ANL') edges ["('ORNL',61):L=297.0893541666667", '(61,58):L=162.2391425', '(58,55):L=162.2391425', '(55,52):L=162.2391425', "(52,'ANL'):L=147.06573833333334"] W 5.0
