# %%
# for max_distance =50
# for q 1.0 F 0.99
user_pairs = ["('NETLPGH', 'PSFC')",
              "('NETLMGN', 'PPPL')", 
              "('BNL', 'JLAB')", "('SRS', 'ORAU')",
              "('Y12', 'FNAL')", "('ORNL', 'ANL')"]
list_of_paths = [#9+9+10+7+7+4
    ["('NETLPGH',80)", "(80,'EQXDC4')",
     "('EQXDC4',112)", '(112,110)',
     "(110,'NEWY1118TH')", "('NEWY1118TH',46)",
     '(46,45)', '(45,44)', '(44,42)', "(42,'PSFC')"], 
    ["('NETLMGN',85)", '(85,84)', '(84,83)', "(83,'EQXDC4')",
     "('EQXDC4','WASH')", "('WASH',117)", '(117,116)', '(116,115)', 
     '(115,114)', "(114,'PPPL')"],
    ["('BNL','NEWY32AOA')", "('NEWY32AOA',109)", '(109,110)', '(110,111)',
     '(111,112)', '(112,113)', "(113,'WASH')", "('WASH',86)", '(86,87)',
     '(87,88)', "(88,'JLAB')"],
    ["('SRS',4)", '(4,3)', '(3,2)', "(2,'ATLA')", "('ATLA',21)",
     '(21,22)', '(22,23)', "(23,'ORAU')"], 
    ["('Y12','CHAT')", "('CHAT','NASH')", "('NASH',59)", 
     '(59,56)', '(56,55)', '(55,53)', "(53,'STAR')", "('STAR','FNAL')"],
    ["('ORNL',61)", '(61,58)', '(58,55)', '(55,52)', "(52,'ANL')"]]
# for q 0.5 F 1.0
user_pairs = ["('NETLPGH', 'PSFC')",
              "('NETLMGN', 'PPPL')",
              "('BNL', 'JLAB')",
              "('SRS', 'ORAU')", 
              "('Y12', 'FNAL')", 
              "('ORNL', 'ANL')"]
list_of_paths = [["('NETLPGH',80)", "(80,'EQXDC4')", "('EQXDC4',112)", 
                  '(112,110)', "(110,'NEWY1118TH')", "('NEWY1118TH',46)",
                  '(46,45)', '(45,44)', '(44,42)', "(42,'PSFC')"], 
                 ["('NETLMGN',85)", '(85,84)', '(84,83)', "(83,'EQXDC4')",
                  "('EQXDC4','WASH')", "('WASH',117)", '(117,116)',
                  '(116,115)', '(115,114)', "(114,'PPPL')"], 
                 ["('BNL','NEWY32AOA')", "('NEWY32AOA',109)", 
                  '(109,110)', '(110,111)', '(111,112)', '(112,113)', "(113,'WASH')",
                  "('WASH',86)", '(86,87)', '(87,88)', "(88,'JLAB')"], 
                 ["('SRS',4)", '(4,3)', '(3,2)', "(2,'ATLA')", "('ATLA',21)",
                  '(21,22)', '(22,23)', "(23,'ORAU')"], 
                 ["('Y12','CHAT')", "('CHAT',61)", '(61,59)', '(59,56)', 
                  '(56,55)', '(55,53)', "(53,'STAR')", "('STAR','FNAL')"], 
                 ["('ORNL',61)", '(61,58)', '(58,55)', '(55,52)', "(52,'ANL')"]]

# %%
# for max_dist=25 
#q=0.5 and F= 1
user_pairs= ["('NETLPGH', 'PSFC')", 
             "('NETLMGN', 'PPPL')", 
             "('BNL', 'JLAB')", "('SRS', 'ORAU')", 
             "('Y12', 'FNAL')", "('ORNL', 'ANL')"]
list_of_paths = [["('NETLPGH',82)", '(82,80)', '(80,77)', '(77,120)',
                  '(120,113)', '(113,41)', "(41,'PSFC')"], 
                 ["('NETLMGN',92)", '(92,88)', "(88,'WASH')", 
                  "('WASH',131)", '(131,128)', '(128,125)', "(125,'PPPL')"], 
                 ["('BNL',111)", '(111,116)', '(116,121)', '(121,98)', "(98,'JLAB')"],
                 ["('SRS',11)", '(11,10)', '(10,8)', '(8,6)', "(6,'ATLA')", 
                  "('ATLA',14)", '(14,16)', '(16,18)', '(18,19)', "(19,'ORAU')"],
                 ["('Y12',28)", '(28,27)', '(27,26)', '(26,21)', '(21,67)', '(67,63)',
                  '(63,102)', "(102,'FNAL')"],
                 ["('ORNL',107)", '(107,106)', '(106,103)', '(103,76)', '(76,71)', 
                  '(71,66)', '(66,64)', '(64,61)', '(61,56)', "(56,'ANL')"]]


#for q= 1.0 and F= 0.99
user_pairs = ["('NETLPGH', 'PSFC')",
              "('NETLMGN', 'PPPL')",
              "('BNL', 'JLAB')", 
              "('SRS', 'ORAU')", "('Y12', 'FNAL')",
              "('ORNL', 'ANL')"]
list_of_paths = [["('NETLPGH',82)", '(82,80)', '(80,77)', '(77,120)', '(120,113)', '(113,41)', "(41,'PSFC')"], 
                 ["('NETLMGN',92)", '(92,88)', "(88,'WASH')", "('WASH',131)", '(131,128)', '(128,125)',
                  "(125,'PPPL')"], 
                 ["('BNL',111)", '(111,116)', '(116,121)', '(121,98)', "(98,'JLAB')"],
                 ["('SRS',11)", '(11,10)', '(10,8)', '(8,6)', "(6,'ATLA')", "('ATLA',14)", 
                  '(14,16)', '(16,18)', '(18,19)', "(19,'ORAU')"], 
                 ["('Y12',28)", '(28,27)', '(27,26)', '(26,21)', '(21,67)', '(67,63)', 
                  '(63,102)', "(102,'FNAL')"], 
                 ["('ORNL',107)", '(107,106)', '(106,103)', '(103,76)', '(76,71)', 
                  '(71,66)', '(66,64)', '(64,61)', '(61,56)', "(56,'ANL')"]]
